# %%
# Librairies nécessaires
import os
import pickle
import fasttext
import re
from gensim.models import Word2Vec, KeyedVectors
from gensim.models.fasttext import load_facebook_model
from top2vec import Top2Vec
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       4 import fasttext
#       5 import re
# ----> 6 from gensim.models import Word2Vec, KeyedVectors
#       7 from gensim.models.fasttext import load_facebook_model
#       8 from top2vec import Top2Vec
#
# File C:\ProgramData\Anaconda3\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.4.0'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File C:\ProgramData\Anaconda3\Lib\site-packages\gensim\parsing\__init__.py:4
#       1 """This package contains functions to preprocess raw text"""
#       3 from .porter import PorterStemmer  # noqa:F401
# ----> 4 from .preprocessing import (  # noqa:F401
#       5     preprocess_documents,
#       6     preprocess_string,
#       7     read_file,
#       8     read_files,
#       9     remove_stopwords,
#      10     split_alphanum,
#      11     stem_text,
#      12     strip_multiple_whitespaces,
#      13     strip_non_alphanum,
#      14     strip_numeric,
#      15     strip_punctuation,
#      16     strip_short,
#      17     strip_tags,
#      18 )
#
# File C:\ProgramData\Anaconda3\Lib\site-packages\gensim\parsing\preprocessing.py:26
#      23 import string
#      24 import glob
# ---> 26 from gensim import utils
#      27 from gensim.parsing.porter import PorterStemmer
#      30 STOPWORDS = frozenset([
#      31     'all', 'six', 'just', 'less', 'being', 'indeed', 'over', 'move', 'anyway', 'four', 'not', 'own', 'through',
#      32     'using', 'fifty', 'where', 'mill', 'only', 'find', 'before', 'one', 'whose', 'system', 'how', 'somewhere',
#    (...)
#      58     'make', 'once'
#      59 ])
#
# File C:\ProgramData\Anaconda3\Lib\site-packages\gensim\utils.py:61
#      58 """An exception that gensim code raises when Cython extensions are unavailable."""
#      60 #: A default, shared numpy-Generator-based PRNG for any/all uses that don't require seeding
# ---> 61 default_prng = np.random.default_rng()
#      64 def get_random_state(seed):
#      65     """Generate :class:`numpy.random.RandomState` based on input seed.
#      66
#      67     Parameters
#    (...)
#      86
#      87     """
#
# AttributeError: module 'numpy' has no attribute 'random'
